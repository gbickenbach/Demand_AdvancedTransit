# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
January = pd.read_csv("drive/MyDrive/FYREE/Pick Up by Day/Demand_January.csv")
January = January.drop(columns = "Unnamed: 0")
February = pd.read_csv("drive/MyDrive/FYREE/Pick Up by Day/Demand_February.csv")
February = February.drop(columns = "Unnamed: 0")
March = pd.read_csv("drive/MyDrive/FYREE/Pick Up by Day/Demand_March.csv")
March = March.drop(columns = "Unnamed: 0")
April = pd.read_csv("drive/MyDrive/FYREE/Pick Up by Day/Demand_April.csv")
April = April.drop(columns = "Unnamed: 0")
May = pd.read_csv("drive/MyDrive/FYREE/Pick Up by Day/Demand_May.csv")
May = May.drop(columns = "Unnamed: 0")
June = pd.read_csv("drive/MyDrive/FYREE/Pick Up by Day/Demand_June.csv")
June = June.drop(columns = "Unnamed: 0")
July = pd.read_csv("drive/MyDrive/FYREE/Pick Up by Day/Demand_July.csv")
July = July.drop(columns = "Unnamed: 0")
August = pd.read_csv("drive/MyDrive/FYREE/Pick Up by Day/Demand_August.csv")
August = August.drop(columns = "Unnamed: 0")
September = pd.read_csv("drive/MyDrive/FYREE/Pick Up by Day/Demand_September.csv")
September = September.drop(columns = "Unnamed: 0")
October = pd.read_csv("drive/MyDrive/FYREE/Pick Up by Day/Demand_October.csv")
October = October.drop(columns = "Unnamed: 0")
November = pd.read_csv("drive/MyDrive/FYREE/Pick Up by Day/Demand_November.csv")
November = November.drop(columns = "Unnamed: 0")
December = pd.read_csv("drive/MyDrive/FYREE/Pick Up by Day/Demand_December.csv")
December = December.drop(columns = "Unnamed: 0")

# %%
january = January
february = February
march = March
april = April
may = May
june = June
july = July
august = August
september = September
october = October
november = November
december = December
january = january.set_index("Station")
february = february.set_index("Station")
march = march.set_index("Station")
april = april.set_index("Station")
may = may.set_index("Station")
june = june.set_index("Station")
july = july.set_index("Station")
august = august.set_index("Station")
september = september.set_index("Station")
october = october.set_index("Station")
november = november.set_index("Station")
december = december.set_index("Station")

# %%
january.loc["Academy Street"].iloc[0]

# %%
#FOR EVERY DAY OF THE MONTH, SAME STATIONS BUT DIFFERENT MONTHS
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)

station = input("Enter a Station: ")


xpoints = may.loc[station].iloc[:,0]
ypoints = may.loc[station].iloc[:,1]


plt.plot(xpoints, ypoints, label='May')
plt.legend()

xpoints = june.loc[station].iloc[:,0]
ypoints = june.loc[station].iloc[:,1]


plt.plot(xpoints, ypoints, label="June")
plt.legend()

plt.show()

# %%
#FOR EVERY DAY OF DIFFERENT MONTH, DIFFERENT STATIONS BUT SAME MONTH
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)

station = input("Enter a Station: ")


xpoints = october.loc[station].iloc[:,0]
ypoints = october.loc[station].iloc[:,1]


plt.plot(xpoints, ypoints, label=station)
plt.legend()

station = input("Enter another Station: ")


xpoints = october.loc[station].iloc[:,0]
ypoints = october.loc[station].iloc[:,1]


plt.plot(xpoints, ypoints, label=station)
plt.legend()

plt.show()
# Out:
# Enter a Station: Academy Street
# Enter another Station: Shaws

# %%
#DONT USE THIS FOR MONTH PART
for i, row in enumerate(August.iloc[:, 1]):
  August.iloc[i, 1] = August.iloc[i, 1] + 31

for i, row in enumerate(September.iloc[:, 1]):
  September.iloc[i, 1] = September.iloc[i, 1] + 62

for i, row in enumerate(October.iloc[:, 1]):
  October.iloc[i, 1] = October.iloc[i, 1] + 92

for i, row in enumerate(November.iloc[:, 1]):
  November.iloc[i, 1] = November.iloc[i, 1] + 123

for i, row in enumerate(December.iloc[:, 1]):
  December.iloc[i, 1] = December.iloc[i, 1] + 153

for i, row in enumerate(January.iloc[:, 1]):
  January.iloc[i, 1] = January.iloc[i, 1] + 184

for i, row in enumerate(February.iloc[:, 1]):
  February.iloc[i, 1] = February.iloc[i, 1] + 215

for i, row in enumerate(March.iloc[:, 1]):
  March.iloc[i, 1] = March.iloc[i, 1] + 243

for i, row in enumerate(April.iloc[:, 1]):
  April.iloc[i, 1] = April.iloc[i, 1] + 274

for i, row in enumerate(May.iloc[:, 1]):
  May.iloc[i, 1] = May.iloc[i, 1] + 304

for i, row in enumerate(June.iloc[:, 1]):
  June.iloc[i, 1] = June.iloc[i, 1] + 335

# %%
year = pd.DataFrame()
year = year.append([July, August, September, October, November, December, January, February, March, April, May, June], ignore_index=True)
year = year.set_index("Station")

# %%
f = plt.figure()
f.set_figwidth(16)
f.set_figheight(5)

station = input("Enter a Station: ")

xpoints = year.loc[station].iloc[:,0]
ypoints = year.loc[station].iloc[:,1]


plt.plot(xpoints, ypoints)


station = input("Enter a second station: ")

xpoints = year.loc[station].iloc[:,0]
ypoints = year.loc[station].iloc[:,1]


plt.plot(xpoints, ypoints)
plt.show()
# Out:
# Enter a Station: Triangle Park
# Enter a second station: Woodbridge

# %%
#From here on I don't know, it can show all stations but it is too crowded

# %%
stats = pd.DataFrame()
stats = stats.append([July, August, September, October, November, December, January, February, March, April, May, June], ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3ba9bd852cdc> in <cell line: 1>()
# ----> 1 stats = pd.DataFrame()
#       2 stats = stats.append([July, August, September, October, November, December, January, February, March, April, May, June], ignore_index=True)
#
# NameError: name 'pd' is not defined

# %%
stationes = pd.DataFrame()
stationes["Station"] = pd.Series(stats["Station"].unique())
stationes = stationes.iloc[10:19]

# %%
stationes

# %%
f = plt.figure()
f.set_figwidth(40)
f.set_figheight(5)
for i, row in enumerate(stationes.iloc[:, 0]):
  xpoints = year.loc[row].iloc[:,0]
  ypoints = year.loc[row].iloc[:,1]


  plt.plot(xpoints, ypoints)
plt.show()

# %%
stationes.iloc[:, 0]
